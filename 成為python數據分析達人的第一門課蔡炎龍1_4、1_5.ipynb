# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pi
# Out:
# 3.141592653589793

# %%
sin(pi/2)
# Out:
# 1.0

# %%
plot([1,2,5,2])

# %%
randn(10)
# Out:
# array([-0.85452733,  0.19814976, -0.93397088, -0.01027247, -0.96457928,
#        -1.81290588,  0.1703043 ,  0.27867925, -1.51196993,  0.17853916])

# %%
plot(randn(60))

# %%
plot([1,7,4],[5,-1,2.3])

# %% [markdown]
# 自由筆記

# %% [markdown]
# # 大標
# ## 中標
# ### 小標

# %% [markdown]
# # 分項說明
# * 用星號
# - 或減號

# %% [markdown]
# # 插入網址
# [費曼學習法實驗室](https://thefeynmantechniquelab.blogspot.com/)
#
# # 插入圖片
# ![my OC](girl.png)

# %% [markdown]
# # 插入網址
# [費曼學習法實驗室](https://thefeynmantechniquelab.blogspot.com/)
#
# # 插入圖片
# ![my OC](girl.png)

# %% [markdown]
# $ y=x^4-2x^2 $
# $$ y=x^4-2x^2 $$
